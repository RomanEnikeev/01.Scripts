# %% [markdown]
# <a href="https://colab.research.google.com/github/RomanEnikeev/01.Scripts/blob/master/Coursework_analytics_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Курсовая работа. Блок 1
# *Pandas и Matplotlib*
#
# **NB!** Код должен быть с комментариями к каждому логическому блоку кода. В противном случае работа **не** будет принята. <br><br>
# Выполнение курсовой работы может потребовать использование дополнительных библиотек.
#
# <br><br>
# **Описание работы:**
#
# Перед вами стоит бизнес-задача – на основании имеющихся данных подготовить аналитический отчет, который в дальнейшем поможет продюсерам образовательных программ эффективно выстраивать стратегию по модернизированию и улучшению курсов. В начале отчета предлагается оформить емкий описательный блок по каждому курсу на основании рассчитанных показателей. Далее предлагается посчитать потенциальную нагрузку на преподавателей, чтобы оценить необходимость расширения штата сотрудников. Затем идет блок из двух пунктов по анализу качества контента курсов, где необходимо выявить проблемные модули, которые, возможно, требуют доработки. Также стоит задача выявить потенциальную сезонность. Наконец, предложено задание для самостоятельной разработки метрики успеваемости студентов для нахождения тех, кто значительно хуже справляются с прохождением курса. Каждый из пунктов анализа предполагается сопроводить аналитическим выводом на основании рассчитанных метрик.
#
# <br><br>
#
# _________
# Обозначения:<br><br>
# &nbsp;&nbsp;&nbsp;&nbsp;**(p)** – задание может быть выполнено после прохождения модулей по Pandas <br>
# &nbsp;&nbsp;&nbsp;&nbsp;**(m)** – задание может быть выполнено после прохождения модуля по Matplotlib <br>
# &nbsp;&nbsp;&nbsp;&nbsp;⭐ – необязательное задание повышенной сложности
# _________
#
# [Codebook](#Codebook) <br>
# [1. Описание и начальная работа с данными](#1.1-Описание-и-начальная-работа-с-данными)<br>
# [2. Расчет потенциальной нагрузки на преподавателей](#2.-Расчет-потенциальной-нагрузки-на-преподавателей)<br>
# [3. Выявление проблемных модулей](#3.-Выявление-проблемных-модулей)<br>
# [4. Расчет конверсии](#4.-Расчет-конверсии) <br>
# [5. Метрика успеваемости ](#5.-Метрика-успеваемости)

# %% [markdown]
# ## Codebook
#
# `courses.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `id` – идентификатор курса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `title` – название курса <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `field` – сфера, к которой относится курс <br> <br><br>
# `students.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `id` – идентификатор студента <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `city` – город студента <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `birthday` – день рождения студента <br> <br><br>
# `course_contents.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `course_id` – идентификатор курса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `module_number` – номер модуля <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `module_title` – название модуля <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `lesson_number` – номер урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `lesson_title` – название урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `lesson_token` – токен урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `is_video` – наличие видео *(true/false)* <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `is_homework` – наличие домашней работы *(true/false)* <br>
# <br><br>
# `progresses.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `id` – идентификатор прогресса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `student_id` – идентификатор студента <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `course_id` – идентификатор курса <br> <br><br>
# `progress_phases.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `progress_id` – идентификатор прогресса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `module_number` – номер модуля <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `lesson_number` – номер урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `status` – статус прохождения урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `start_date` – дата начала <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `finish_date` – дата окончания <br>
# <br><br>

# %% [markdown]
# ## 1. Описание и начальная работа с данными
#
# Вам необходимо подготовить данные и описать их. Данные реальные и содержат пропущенные значения, а также лишние относительно друг друга данные. <br>
#
# Объедините датасеты (кроме `students.scv`) в один общий для дальнейшей работы. Отдельный датасет создайте для расчета среднего возраста студентов курсов (отдельный датасет со `students.scv` нужен, чтобы в основном не потерять значения в основном датасете из-за того, что не по всем студентам есть анкетные данные о дате рождения). <br> <br>
# Опишите данные: <br>
# 1. **(p)** Посчитайте
#       * общее количество курсов в датасете,
#       * количество модулей на каждом курсе,
#       * количество уроков в каждом модуле на каждом курсе,
#       * медианное количество уроков в модуле на каждом курсе,
#       * количество учеников на каждом курсе
#       * минимальный, максимальный, средний, медианный возраст студентов
#       * минимальный, максимальный, средний, медианный возраст студентов на каждом курсе
# 2. **(m)** Постройте bar-chart, отражающий количество студентов на каждом курсе. Ticks нужно развернуть так, чтобы они были читаемы
# 3. **(m)** Постройте горизонтальный (столбцы должны располагаться горизонтально) bar-chart, отражающий количество студентов на каждом курсе. График должен иметь заголовок. Значения должны быть отсортированы. Цвет столбцов должен содержать информацию о сфере, к которой относится курс (то есть нужна легенда). Прозрачность должна стоять на отметке 0.1. На график должна быть нанесена линия медианы. У медианы должен быть свой цвет. Рамки у графика быть не должно ⭐
# 4.     На основании рассчитанных значений опишите данные (описание должно быть полным и покрывать все полученные выше метрики)
#
# _____________________________________________________________________

# %% [markdown]
# Для того, чтобы проверить, что вы правильно соединили все датасеты в основной (без `students.csv`), запустите аналогичный приведенному ниже запрос. Выдача должна совпадать. Имейте в виду, что названия некоторых столбцов были переименованы.

# %%
#main[main.student_id == '768c2987a744c51ce64a5993a2a94eaf'] # проверка основного датасета

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import dask.dataframe as dd
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
from google.colab import drive
#drive.mount('/content/drive')
import datetime
# %matplotlib inline

# import warnings
# warnings.filterwarnings('ignore')

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
def create_param_like_csv(file_list, directory):
  for file in file_list:
    name_param_without_csv = file['title'][:-4]
    name_param_with_csv = file['title']
    #return name_param_like_with_csv, type('name_param_like_with_csv')
    file_id = file['id']
    #return name_param_like_with_csv
    downloaded = drive.CreateFile({'id':file_id}) 
    downloaded.GetContentFile(name_param_with_csv)  
    globals()[name_param_without_csv] = pd.read_csv(name_param_with_csv)

directory = '/content/drive/My Drive/Skillbox_DataScience/Data_1/Data/'                           #директория к папке с файлами
file_list = drive.ListFile({'q': "'1MqC3s4t8Z-61JgDk3yUSkJ6vWLNMMEBG' in parents"}).GetList()     #список файлов в папке, внутри id папки

create_param_like_csv(file_list, directory)    #создаем параметры-датафреймы с имненами таблиц(у таблицы students.csv будет параметр students)

courses.head()
progress_phases.head()
# Out:
#                         progress_id  ...                    finish_date
# 0  a387ab916f402cb3fbfffd29f68fd0ce  ...  2018-06-23 08:28:52.439542+00
# 1  a387ab916f402cb3fbfffd29f68fd0ce  ...  2018-06-20 15:45:07.717209+00
# 2  a387ab916f402cb3fbfffd29f68fd0ce  ...  2018-06-23 08:18:12.784616+00
# 3  a387ab916f402cb3fbfffd29f68fd0ce  ...  2018-06-21 19:09:30.845034+00
# 4  a387ab916f402cb3fbfffd29f68fd0ce  ...  2018-06-28 15:59:25.320418+00
#
# [5 rows x 6 columns]

# %%
data = pd.merge(progress_phases, progresses, left_on='progress_id', right_on='id', how='left') 
#соединяю две таблицы по progress_phases, по самой большой
data.drop(['id'], axis=1, inplace=True)

data.head()
len(data)
# Out:
# 350677

# %%
data = pd.merge(data, courses, left_on='course_id', right_on='id', how='left') 
#соединяю две таблицы data и courses, по самой большой
#data.drop(['id'], axis=1, inplace=True)
data.head()
len(data)
# Out:
# 350677

# %%
##появляются дублированные айдишники - убираю их и сохраняю изменения
data.drop(data.columns[-4],axis=1, inplace=True)
data.drop(data.columns[-3],axis=1, inplace=True)
data.head()
# Out:
#                         progress_id  module_number  ...               title   field
# 0  a387ab916f402cb3fbfffd29f68fd0ce              2  ...  Веб-дизайн PRO 2.0  Design
# 1  a387ab916f402cb3fbfffd29f68fd0ce              1  ...  Веб-дизайн PRO 2.0  Design
# 2  a387ab916f402cb3fbfffd29f68fd0ce              2  ...  Веб-дизайн PRO 2.0  Design
# 3  a387ab916f402cb3fbfffd29f68fd0ce              1  ...  Веб-дизайн PRO 2.0  Design
# 4  a387ab916f402cb3fbfffd29f68fd0ce              1  ...  Веб-дизайн PRO 2.0  Design
#
# [5 rows x 10 columns]

# %%
len(data)
# Out:
# 350677

# %%
data = pd.merge(data, course_contents, left_on=['course_id', 'module_number', 'lesson_number'], right_on=['course_id', 'module_number', 'lesson_number'], how='left') 
#тут тоже соединяем, общих стобцов больше

data.head()
data[data.student_id == '768c2987a744c51ce64a5993a2a94eaf']  #проверка верности полученного дф
# Out:
#                              progress_id  module_number  ...  is_video is_homework
# 0       a387ab916f402cb3fbfffd29f68fd0ce              2  ...      True       False
# 1       a387ab916f402cb3fbfffd29f68fd0ce              1  ...      True       False
# 2       a387ab916f402cb3fbfffd29f68fd0ce              2  ...      True       False
# 3       a387ab916f402cb3fbfffd29f68fd0ce              1  ...      True       False
# 4       a387ab916f402cb3fbfffd29f68fd0ce              1  ...     False        True
# 5       a387ab916f402cb3fbfffd29f68fd0ce              2  ...      True       False
# 6       a387ab916f402cb3fbfffd29f68fd0ce              1  ...      True       False
# 7       a387ab916f402cb3fbfffd29f68fd0ce              2  ...     False        True
# 8       a387ab916f402cb3fbfffd29f68fd0ce              1  ...      True       False
# 9       a387ab916f402cb3fbfffd29f68fd0ce              1  ...      True       False
# 10      a387ab916f402cb3fbfffd29f68fd0ce              2  ...      True       False
# 112420  6407c290505e790e92207a1dbc41a2cd              1  ...      True       False
# 132870  5767046d89ed7563a0c3a9a3896a23e6              1  ...     False        True
# 132871  5767046d89ed7563a0c3a9a3896a23e6              2  ...      True       False
# 132872  5767046d89ed7563a0c3a9a3896a23e6              1  ...      True       False
# 132873  5767046d89ed7563a0c3a9a3896a23e6              1  ...      True       False
# 132874  5767046d89ed7563a0c3a9a3896a23e6              2  ...      True       False
# 132875  5767046d89ed7563a0c3a9a3896a23e6              2  ...     False        True
# 155020  c90ebe1431eac5cbb11692100b7a0f8d              1  ...      True       False
# 155021  c90ebe1431eac5cbb11692100b7a0f8d              1  ...      True       False
# 155022  c90ebe1431eac5cbb11692100b7a0f8d              1  ...     False        True
# 155023  c90ebe1431eac5cbb11692100b7a0f8d              1  ...      True       False
# 155024  c90ebe1431eac5cbb11692100b7a0f8d              1  ...      True       False
# 155025  c90ebe1431eac5cbb11692100b7a0f8d              1  ...      True       False
# 155026  c90ebe1431eac5cbb11692100b7a0f8d              1  ...      True       False
#
# [25 rows x 15 columns]

# %%
len(data)
# Out:
# 350677

# %%
title_courses = data.groupby(['title']).mean()   ##группируем по названию курса и выводим количество строк

##общее количество курсов в датасете
len(title_courses)
# Out:
# 15

# %%
##для себя
data.groupby(['title']).mean()   ##просто смотрю сгруппированные данные
# Out:
#                                      module_number  ...  is_homework
# title                                               ...
# Excel Базовый                             3.245527  ...     0.154666
# Java-разработчик                          4.120682  ...     0.120724
# Java-разработчик c нуля                   3.395007  ...     0.189148
# JavaScript с нуля                         4.723192  ...     0.123004
# PHP-разработчик с 0 до PRO. Часть 1       2.863887  ...     0.206172
# SMM-маркетолог от А до Я                  3.242846  ...     0.138267
# UX-дизайн                                 3.907676  ...     0.142093
# Анимация интерфейсов                      5.139633  ...     0.247431
# Веб-вёрстка для начинающих 2.0            2.862969  ...     0.141308
# Веб-дизайн PRO 2.0                        4.698633  ...     0.187978
# Веб-дизайн Базовый                        6.032806  ...     0.168430
# Веб-дизайн с нуля 2.0                     7.198612  ...     0.173799
# Веб-разработчик                           5.698234  ...     0.457347
# Интернет-маркетолог от Ingate             4.837121  ...     0.106401
# Руководитель digital-проектов             6.578595  ...     0.202973
#
# [15 rows x 4 columns]

# %%
##для себя
##пробую разные группировки-агрегирования
test_group = data.groupby(['title', 'module_title']).agg(np.median)
test_group.loc[[test_group.index.get_level_values(0)[1]]]['lesson_number']
# Out:
# title          module_title
# Excel Базовый   Визуализация данных Excel                                     3.0
#                Основной функционал Excel                                      5.0
#                Основной функционал Excel (продолжение)                        4.0
#                Сводные таблицы Excel                                          3.0
#                Формулы и функции Excel. Более сложные формулы                 3.0
#                Формулы и функции Excel. Введение                              2.0
#                Формулы и функции Excel. Продолжаем работать с формулами       4.0
#                Формулы и функции Excel. Работа с ошибками, проверка данных    3.0
#                Экзаменационная работа                                         1.0
# Name: lesson_number, dtype: float64

# %%
##количество модулей на каждом курсе
module_title_corses = data.groupby(['title']).agg({"module_title": "nunique"})   ##пытаюсь группировать и агрегировать по названию курса и по module_title
module_title_corses
# Out:
#                                      module_title
# title
# Excel Базовый                                   9
# Java-разработчик                               17
# Java-разработчик c нуля                         9
# JavaScript с нуля                              18
# PHP-разработчик с 0 до PRO. Часть 1             8
# SMM-маркетолог от А до Я                       11
# UX-дизайн                                      20
# Анимация интерфейсов                           21
# Веб-вёрстка для начинающих 2.0                  8
# Веб-дизайн PRO 2.0                             17
# Веб-дизайн Базовый                             17
# Веб-дизайн с нуля 2.0                          19
# Веб-разработчик                                20
# Интернет-маркетолог от Ingate                  18
# Руководитель digital-проектов                  17

# %%
##количество уроков в каждом модуле на каждом курсе

module_title_corses = data.groupby(['title', 'module_title']).agg({"lesson_title": "nunique"})
##пытаюсь группировать по названию курса и по module_title 

module_title_corses
# Out:
#                                                                                   lesson_title
# title                         module_title
# Excel Базовый                  Визуализация данных Excel                                     5
#                               Основной функционал Excel                                     11
#                               Основной функционал Excel (продолжение)                        7
#                               Сводные таблицы Excel                                          5
#                               Формулы и функции Excel. Более сложные формулы                 5
# ...                                                                                        ...
# Руководитель digital-проектов Решение факапов. Lean/TOC. Обзор.                              5
#                               Требовательность digital-продюсера                             4
#                               Управление временем                                            4
#                               Управление дизайнерами. Разработка дизайна по s...             7
#                               Экологичный путь менеджера                                     4
#
# [229 rows x 1 columns]

# %%
##для себя
##попытка - удачно. хорошо сгруппировали. хочу достать всю строчку "Excel Базовый"
lesson_module_title_corses = data.groupby(['title', 'module_title', 'lesson_title']).agg({'lesson_title': 'nunique'})
lesson_module_title_corses
lesson_module_title_corses.loc[[lesson_module_title_corses.index.get_level_values(0)[6]]]  ## .index.get_level_values(0)[1] - берет первую строчку и 
#lesson_module_title_corses.index.get_level_values(0)[99]
# for key, item in lesson_module_title_corses:
#     print(lesson_module_title_corses.get_group(key), "\n\n")
# Out:
#                                                                                                                      lesson_title
# title         module_title                                       lesson_title
# Excel Базовый  Визуализация данных Excel                         Графики и диаграммы в Excel                                    1
#                                                                  Домашняя работа                                                1
#                                                                  Макеты и стили диаграмм                                        1
#                                                                  Условное форматирование                                        1
#                                                                  Фильтр и сортировка по цвету                                   1
#               Основной функционал Excel                          Введение                                                       1
#                                                                  Домашняя работа                                                1
#                                                                  Знакомство с интерфейсом Excel, структура «рабо...             1
#                                                                  Многокритериальная сортировка (по нескольким по...             1
#                                                                  Отмена действий в Excel. «Горячие» клавиши Ctrl...             1
#                                                                  Работа с листами рабочей книги Excel. Создание,...             1
#                                                                  Создание первой таблицы, заполнение «шапки» и з...             1
#                                                                  Сортировка (упорядочение записей таблицы по кри...             1
#                                                                  Фильтры в Excel. Сложные условия фильтрации (чи...             1
#                                                                  Фильтры в Excel. Фильтрация по нескольким полям                1
#                                                                  Фильтры в Excel. Фильтрация по одному полю                     1
#               Основной функционал Excel (продолжение)            «Протягивание» (автозаполнение) значений в ячей...             1
#                                                                  Введение                                                       1
#                                                                  Домашняя работа                                                1
#                                                                  Инструмент «Текст по столбцам». Разделение данн...             1
#                                                                  Копирование, вырезание, вставка строк, столбцов...             1
#                                                                  Работа с большими таблицами: масштаб, закреплен...             1
#                                                                  Удаление дубликатов. По одному полю, по всем по...             1
#               Сводные таблицы Excel                              Домашняя работа                                                1
#                                                                  Проценты, вычисляемые поля                                     1
#                                                                  Создание, преобразование, фильтрация                           1
#                                                                  Срезы, сводные диаграммы                                       1
#                                                                  Фильтрация, форматирование, дополнительные поля                1
#               Формулы и функции Excel. Более сложные формулы     Домашняя работа                                                1
#                                                                  Комбинация нескольких условий. Функция И.                      1
#                                                                  Комбинация нескольких условий. Функция ИЛИ.                    1
#                                                                  Функции СЧЁТЕСЛИ, СУММЕСЛИ. Подсчёт и подсуммир...             1
#                                                                  Функции СЧЁТЕСЛИМН, СУММЕСЛИМН. Операторы для в...             1
#               Формулы и функции Excel. Введение                  Виды функций. Способы ввода функций. Поиск функ...             1
#                                                                  Домашняя работа                                                1
#                                                                  Начало работы с формулами. Простейшие формулы (...             1
#               Формулы и функции Excel. Продолжаем работать с ... Вложенные формулы, принципы последовательного с...             1
#                                                                  Домашняя работа                                                1
#                                                                  Способы ввода функций. Просмотр подсказок и спр...             1
#                                                                  Текстовые формулы СЖПРОБЕЛЫ, ПРОПНАЧ, ЛЕВСИМВ, ...             1
#                                                                  Функция ВПР с интервальным просмотром                          1
#                                                                  Функция ГПР. Аналог ВПР для просмотра вдоль строк.             1
#                                                                  Функция ЕСЛИ. Вывод различных значений в зависи...             1
#               Формулы и функции Excel. Работа с ошибками, про... Домашняя работа                                                1
#                                                                  Именованные диапазоны                                          1
#                                                                  Инструмент “Проверка данных”                                   1
#                                                                  Ошибки в формулах, обработка. Функция ЕСЛИОШИБКА               1
#                                                                  Функции ИНДЕКС, ПОИСКПОЗ. Расширенный аналог фу...             1
#               Экзаменационная работа                             Экзаменационная работа                                         1

# %%
##количество уроков в модуле на каждом курсе
nunique_lesson_module_title_corses = data.groupby(['title', 'module_title']).nunique().lesson_number
## ИСПРАВЛЕНИЕ!!
## медианное количество уроков на курсе
nunique_lesson_module_title_corses.groupby('title').agg('median')
# Out:
# title
# Excel Базовый                           5.0
# Java-разработчик                        7.0
# Java-разработчик c нуля                13.0
# JavaScript с нуля                       7.0
# PHP-разработчик с 0 до PRO. Часть 1     4.0
# SMM-маркетолог от А до Я                6.0
# UX-дизайн                               3.5
# Анимация интерфейсов                    3.0
# Веб-вёрстка для начинающих 2.0          7.0
# Веб-дизайн PRO 2.0                      5.0
# Веб-дизайн Базовый                      3.0
# Веб-дизайн с нуля 2.0                   4.0
# Веб-разработчик                         2.0
# Интернет-маркетолог от Ingate           6.5
# Руководитель digital-проектов           5.0
# Name: lesson_number, dtype: float64

# %%
##количество учеников на каждом курсе
count_stud_cour = data.groupby(['title']).agg({'student_id': 'nunique'})
# len(data['student_id'].value_counts())   ##9794
count_stud_cour.head()
# Out:
#                                      student_id
# title
# Excel Базовый                               782
# Java-разработчик                            763
# Java-разработчик c нуля                     581
# JavaScript с нуля                           966
# PHP-разработчик с 0 до PRO. Часть 1         854

# %%
data.head()
# Out:
#                         progress_id  module_number  ...  is_video is_homework
# 0  a387ab916f402cb3fbfffd29f68fd0ce              2  ...      True       False
# 1  a387ab916f402cb3fbfffd29f68fd0ce              1  ...      True       False
# 2  a387ab916f402cb3fbfffd29f68fd0ce              2  ...      True       False
# 3  a387ab916f402cb3fbfffd29f68fd0ce              1  ...      True       False
# 4  a387ab916f402cb3fbfffd29f68fd0ce              1  ...     False        True
#
# [5 rows x 15 columns]

# %%
students_drop = students.dropna()                                                          ##убираем незаполненные данные
students_drop['birthday'] = pd.to_datetime(students_drop['birthday'], errors='coerce')     ##конвектируем дату рождения в тип datetime, вычисляя и ошибочные данные (отрицательный возраст или слишком большой)
now = pd.Timestamp('now')                                                                  ##создаем текущее время
students_drop['age'] = (now - students_drop['birthday']).astype('<m8[Y]')                  ##вычисляем возраст студентов и оставляем только год 'Y'
students_drop['age'].describe()                                                            ##видим ошибочные данные, отрицательный возраст и "слишком старого человека"

#print(len(students_drop))                                                               
students_drop = students_drop[(students_drop['age'] > 12) & (students_drop['age'] < 99)]   ##убираю выбросы в возрасте
#print(len(students_drop))
students_drop['age'].describe()                                                            ##минимальный(min), максимальный(max), средний(mean), медианный(50%) возраст студентов
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# count    11266.000000
# mean        29.927215
# std          7.300854
# min         13.000000
# 25%         25.000000
# 50%         29.000000
# 75%         34.000000
# max         97.000000
# Name: age, dtype: float64

# %%
##добавляю к общему датасету students.csv с возрастом
students_drop.drop(['id_'], axis=1, inplace=True)
students_data = pd.merge(data, students_drop, left_on= 'student_id', right_on='id', how='inner')
students_data.head()
# Out:
#                         progress_id  module_number  ...   birthday   age
# 0  a387ab916f402cb3fbfffd29f68fd0ce              2  ... 1984-11-30  35.0
# 1  a387ab916f402cb3fbfffd29f68fd0ce              1  ... 1984-11-30  35.0
# 2  a387ab916f402cb3fbfffd29f68fd0ce              2  ... 1984-11-30  35.0
# 3  a387ab916f402cb3fbfffd29f68fd0ce              1  ... 1984-11-30  35.0
# 4  a387ab916f402cb3fbfffd29f68fd0ce              1  ... 1984-11-30  35.0
#
# [5 rows x 19 columns]

# %%
##убираю дублированный столбец id
students_data.drop(['id'], axis=1, inplace=True)    
students_data.head()
# Out:
#                         progress_id  module_number  ...   birthday   age
# 0  a387ab916f402cb3fbfffd29f68fd0ce              2  ... 1984-11-30  35.0
# 1  a387ab916f402cb3fbfffd29f68fd0ce              1  ... 1984-11-30  35.0
# 2  a387ab916f402cb3fbfffd29f68fd0ce              2  ... 1984-11-30  35.0
# 3  a387ab916f402cb3fbfffd29f68fd0ce              1  ... 1984-11-30  35.0
# 4  a387ab916f402cb3fbfffd29f68fd0ce              1  ... 1984-11-30  35.0
#
# [5 rows x 18 columns]

# %%
##bar-chart, отражающий количество студентов на каждом курсе. Ticks читаемы
sh = students_data.groupby(['title']).agg({'student_id':'count'})
sh.sort_values('student_id', inplace=True)
plt.xticks(rotation=90)
plt.title('Количество студентов на курсах', fontsize=15)
plt.xlabel('Названия курсов')
plt.ylabel('Количество студентов')
gr_courses = sh.index.to_list()
gr_students = sh.values.ravel()
plt.bar(gr_courses, gr_students)
# Out:
# <BarContainer object of 15 artists>

# %%
olds = students_data.groupby(['title']).agg({'age':'mean'})
gr_courses
# Out:
# ['SMM-маркетолог от А до Я',
#  'Веб-разработчик',
#  'PHP-разработчик с 0 до PRO. Часть 1',
#  'Анимация интерфейсов',
#  'Java-разработчик c нуля',
#  'Excel Базовый',
#  'Руководитель digital-проектов',
#  'Веб-дизайн Базовый',
#  'Веб-дизайн PRO 2.0',
#  'JavaScript с нуля',
#  'UX-дизайн',
#  'Java-разработчик',
#  'Веб-вёрстка для начинающих 2.0',
#  'Интернет-маркетолог от Ingate',
#  'Веб-дизайн с нуля 2.0']

# %%
sh = students_data.groupby(['title']).agg({'student_id':'count', 'age': 'mean'})

sh.sort_values('student_id', inplace=True)

plt.subplot(2, 1, 1)
plt.xticks(rotation=90)
plt.title('Количество студентов на курсах', fontsize=15)
plt.xlabel('Названия курсов')
plt.ylabel('Количество студентов')
gr_courses = sh.index.to_list()
gr_students = sh['student_id'].values.ravel()
plt.bar(gr_courses, gr_students)

plt.subplot(2, 1, 2)
gr_courses1 = sh.index.to_list()
gr_students1 = sh['age'].values.ravel()
plt.bar(gr_courses1, gr_students1)
# Out:
# <BarContainer object of 15 artists>

# %%
sh = students_data.groupby(['title']).agg({'student_id':'count', 'age': 'median'})

sh.sort_values('student_id', inplace=True)

fig, ax = plt.subplots(nrows=2, ncols=1, sharex=True, figsize=(10, 10))

# plt.subplot(2, 1, 1)
# plt.xticks(rotation=90)
# plt.title('Количество студентов на курсах', fontsize=15)
# plt.xlabel('Названия курсов')
# plt.ylabel('Количество студентов')
# gr_courses = sh.index.to_list()
# gr_students = sh['student_id'].values.ravel()
ax[0].bar(gr_courses, gr_students)
print(dir(ax[0]))
ax[0].set_ylabel('Количество студентов', fontsize=13)

# fig, axs = plt.subplots(2, 2, figsize=(12, 7))
# axs[0, 0].plot(x, y1, '-')
# axs[0, 1].plot(x, y2, '--')
# axs[1, 0].plot(x, y3, '-.')

# plt.subplot(2, 1, 2)
# gr_courses1 = sh.index.to_list()
# gr_students1 = sh['age'].values.ravel()
ax[1].bar(gr_courses1, gr_students1, color=np.random.rand(3))
ax[1].tick_params(labelrotation=90)
ax[1].set_ylabel('Возраст', fontsize=13)
ax[1].set_xlabel('Названия курсов', fontsize=13)
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_add_text', '_adjustable', '_agg_filter', '_alpha', '_anchor', '_animated', '_aspect', '_autoscaleXon', '_autoscaleYon', '_autotitlepos', '_axes', '_axes_class', '_axes_locator', '_axisbelow', '_clipon', '_clippath', '_contains', '_convert_dx', '_current_image', '_default_contains', '_facecolor', '_frameon', '_gci', '_gen_axes_patch', '_gen_axes_spines', '_get_axis_list', '_get_axis_map', '_get_clipping_extent_bbox', '_get_lines', '_get_patches_for_fill', '_get_view', '_gid', '_gridOn', '_in_layout', '_init_axis', '_label', '_layoutbox', '_left_title', '_make_twin_axes', '_mouseover', '_mouseover_set', '_navigate', '_navigate_mode', '_oid', '_on_units_changed', '_originalPosition', '_parse_scatter_color_args', '_path_effects', '_pcolorargs', '_picker', '_position', '_poslayoutbox', '_process_unit_info', '_prop_order', '_propobservers', '_quiver_units', '_rasterization_zorder', '_rasterized', '_remove_legend', '_remove_method', '_request_autoscale_view', '_right_title', '_sci', '_set_artist_props', '_set_gc_clip', '_set_lim_and_transforms', '_set_position', '_set_title_offset_trans', '_set_view', '_set_view_from_bbox', '_shared_x_axes', '_shared_y_axes', '_sharex', '_sharey', '_sketch', '_snap', '_stale', '_stale_viewlim_x', '_stale_viewlim_y', '_sticky_edges', '_subplotspec', '_tight', '_transform', '_transformSet', '_twinned_axes', '_unstale_viewLim', '_update_image_limits', '_update_line_limits', '_update_patch_limits', '_update_title_position', '_update_transScale', '_url', '_use_sticky_edges', '_validate_converted_limits', '_viewLim', '_visible', '_xaxis_transform', '_xcid', '_xmargin', '_yaxis_transform', '_ycid', '_ymargin', 'acorr', 'add_artist', 'add_callback', 'add_child_axes', 'add_collection', 'add_container', 'add_image', 'add_line', 'add_patch', 'add_table', 'aname', 'angle_spectrum', 'annotate', 'apply_aspect', 'arrow', 'artists', 'autoscale', 'autoscale_view', 'axes', 'axhline', 'axhspan', 'axis', 'axison', 'axvline', 'axvspan', 'bar', 'barbs', 'barh', 'bbox', 'boxplot', 'broken_barh', 'bxp', 'callbacks', 'can_pan', 'can_zoom', 'change_geometry', 'child_axes', 'cla', 'clabel', 'clear', 'clipbox', 'cohere', 'colNum', 'collections', 'containers', 'contains', 'contains_point', 'contour', 'contourf', 'convert_xunits', 'convert_yunits', 'csd', 'dataLim', 'drag_pan', 'draw', 'draw_artist', 'end_pan', 'errorbar', 'eventplot', 'eventson', 'figbox', 'figure', 'fill', 'fill_between', 'fill_betweenx', 'findobj', 'fmt_xdata', 'fmt_ydata', 'format_coord', 'format_cursor_data', 'format_xdata', 'format_ydata', 'get_adjustable', 'get_agg_filter', 'get_alpha', 'get_anchor', 'get_animated', 'get_aspect', 'get_autoscale_on', 'get_autoscalex_on', 'get_autoscaley_on', 'get_axes_locator', 'get_axisbelow', 'get_children', 'get_clip_box', 'get_clip_on', 'get_clip_path', 'get_contains', 'get_cursor_data', 'get_data_ratio', 'get_data_ratio_log', 'get_default_bbox_extra_artists', 'get_facecolor', 'get_fc', 'get_figure', 'get_frame_on', 'get_geometry', 'get_gid', 'get_gridspec', 'get_images', 'get_in_layout', 'get_label', 'get_legend', 'get_legend_handles_labels', 'get_lines', 'get_navigate', 'get_navigate_mode', 'get_path_effects', 'get_picker', 'get_position', 'get_rasterization_zorder', 'get_rasterized', 'get_renderer_cache', 'get_shared_x_axes', 'get_shared_y_axes', 'get_sketch_params', 'get_snap', 'get_subplotspec', 'get_tightbbox', 'get_title', 'get_transform', 'get_transformed_clip_path_and_affine', 'get_url', 'get_visible', 'get_window_extent', 'get_xaxis', 'get_xaxis_text1_transform', 'get_xaxis_text2_transform', 'get_xaxis_transform', 'get_xbound', 'get_xgrid ...
# Text(0.5, 0, 'Названия курсов')

# %%
##ЧТо пытаюсь сделать? Разные цвета для каждой категории. Не могу присвоить колонке array или листы
bar1 = students_data.groupby(['field','title']).agg({'student_id':'count'})
# bar1['color'] = [[1, 2, 3]] * bar1.shape[0]
# bar1

# bar1[bar1['field'] == 'Business'] = 'g'
bar1 = bar1.reset_index()
# # bar1[
# #      (bar1['field'] == 'Business')
# #       | 
# #      (bar1['field'] == 'Design')]['color'] 
# #color=np.random.rand(3,1)
# #bar1.loc[bar1.field=='Business', 'color'] = bar1.color.str.replace('r', 'b')
uni_courses = pd.unique(bar1.field)
# colors = np.array(['r', 'b', 'g'])
# bar1
# # for cour in uni_courses:
# # #   bar1.loc[bar1.field==str(cour), 'color'] = bar1.color.str.replace('r', str(np.random.rand(3,1)))
# #   bar1.loc[bar1.field == cour, 'color'] = np.random.rand(3).tolist()
# np.random.rand(3)
# uni_courses
# np.random.rand(3).tolist()

# %%
uni_courses, [np.random.rand(3) for i in range(len(uni_courses))]
bar1
# Out:
#           field                                title  student_id
# 0      Business                        Excel Базовый        9884
# 1      Business        Руководитель digital-проектов       11996
# 2        Design                            UX-дизайн       17681
# 3        Design                 Анимация интерфейсов        4950
# 4        Design                   Веб-дизайн PRO 2.0       15187
# 5        Design                   Веб-дизайн Базовый       12858
# 6        Design                Веб-дизайн с нуля 2.0       58238
# 7   Development                     Java-разработчик       19974
# 8   Development              Java-разработчик c нуля        7130
# 9   Development                    JavaScript с нуля       16593
# 10  Development  PHP-разработчик с 0 до PRO. Часть 1        4815
# 11  Development       Веб-вёрстка для начинающих 2.0       22723
# 12  Development                      Веб-разработчик        4173
# 13    Marketing             SMM-маркетолог от А до Я        3515
# 14    Marketing        Интернет-маркетолог от Ingate       50509

# %%
#### создаю колонку с цветом на графике по 'field'
field_color = pd.DataFrame({'field': uni_courses, 'color':  [np.random.rand(3) for i in range(len(uni_courses))]})  #[np.nan*len(uni_courses)

bar1 = pd.merge(bar1, field_color, how='inner')
bar1
# Out:
#           field  ...                                              color
# 0      Business  ...  [0.5318085768764672, 0.8756468037513497, 0.738...
# 1      Business  ...  [0.5318085768764672, 0.8756468037513497, 0.738...
# 2        Design  ...  [0.9459594866638297, 0.4920651153055037, 0.006...
# 3        Design  ...  [0.9459594866638297, 0.4920651153055037, 0.006...
# 4        Design  ...  [0.9459594866638297, 0.4920651153055037, 0.006...
# 5        Design  ...  [0.9459594866638297, 0.4920651153055037, 0.006...
# 6        Design  ...  [0.9459594866638297, 0.4920651153055037, 0.006...
# 7   Development  ...  [0.31480330060628126, 0.6797073950112004, 0.55...
# 8   Development  ...  [0.31480330060628126, 0.6797073950112004, 0.55...
# 9   Development  ...  [0.31480330060628126, 0.6797073950112004, 0.55...
# 10  Development  ...  [0.31480330060628126, 0.6797073950112004, 0.55...
# 11  Development  ...  [0.31480330060628126, 0.6797073950112004, 0.55...
# 12  Development  ...  [0.31480330060628126, 0.6797073950112004, 0.55...
# 13    Marketing  ...  [0.031710936220630925, 0.39612403183596623, 0....
# 14    Marketing  ...  [0.031710936220630925, 0.39612403183596623, 0....
#
# [15 rows x 4 columns]

# %%
uni_courses
bar1['field']
# Out:
# 0        Business
# 1        Business
# 2          Design
# 3          Design
# 4          Design
# 5          Design
# 6          Design
# 7     Development
# 8     Development
# 9     Development
# 10    Development
# 11    Development
# 12    Development
# 13      Marketing
# 14      Marketing
# Name: field, dtype: object

# %%
##сортирую значения
fig, ax = plt.subplots()
bar1.sort_values('student_id', inplace=True)
h = plt.barh(bar1.title, bar1.student_id, color = bar1['color'],  alpha=0.5)
plt.legend(h, bar1['field'].drop_duplicates())
bar1.student_id.median()     ##ищем медиану по количеству студентов
ax.set_frame_on(False)      #убираем прямоугольник вокруг графика
ax.vlines(x= bar1['student_id'].median(axis=0), ymin = -1, ymax= 15, linestyle = '--',linewidth = 2, color = 'r')     ##рисуем вертикальную линию по студентам, задавая вернюю и нижнюю крайние точки, тип линии, толщину и цвет

# %% [markdown]
# ## 2. Расчет потенциальной нагрузки на преподавателей
#
# 1. **(p)** Рассчитать прирост студентов на каждом курсе в каждом месяце за всю историю (каждый месяц в диапазоне от марта 2016 до июля 2019 включительно). Считать дату начала прохождения курса студентом по дате начала первой домашней работы.
# 2. **(m)** На основании первого пункта построить line-graph с приростом студентов в каждом месяце для каждого курса. 15 графиков. Графики должны иметь заголовки, оси должны быть подписаны. Ticks нужно развернуть так, чтобы они были читаемы.
# 3. **(m)** На основании первого пункта построить line-graph с несколькими линиями, отражающими прирост студентов в каждом месяце для каждого курса. 15 линий на графике. Ticks нужно развернуть так, чтобы они были читаемы. График должен иметь заголовок. Ось, отражающая прирост, должна быть подписана. Линия для каждого курса должна иметь свой цвет (нужна легенда). Рамок у графика быть не должно ⭐
# 4. **(p)** Рассчитать количество прогрессов по выполнению домашних работ в каждом месяце за всю историю (каждый месяц в диапазоне от марта 2016 до июля 2019 включительно) для каждого курса. Учитывать, что выполнение домашнего задания может перетекать из одного месяца в другой (такие дз надо включать в общее число прогрессов для всех месяцев, которые покрывает срок выполнения этих дз)
# 5. **(m)** Построить line-graph по четвертому пункту. 15 графиков. Графики должны иметь заголовки, оси должны быть подписаны. Ticks нужно развернуть так, чтобы они были читаемы
# 6. **(m)** Построить один line-graph для всех курсов по четвертому пункту. 15 линий на графике. Ticks нужно развернуть так, чтобы они были читаемы. График должен иметь заголовок. Ось, отражающая количество прогрессов, должна быть подписана. Линия для каждого курса должна иметь свой цвет (нужна легенда). Рамок у графика быть не должно ⭐
# 7. На основании рассчитанных значений сделайте аналитический вывод (должен быть полным и покрывать все полученные выше метрики)

# %%
##формируем столбец с датой начала и датой конца сдачи домашних работ
data.info()
data['start_date'] = pd.to_datetime(data['start_date'])#, errors = 'coerce') #, errors='coerce'
data['finish_date'] = pd.to_datetime(data['finish_date'])#, errors = 'coerce')
data.info()
# data['start_date'][0]
# data.head()
# data['start_date'] = data['start_date'].dt.strftime("%m/%y")
# data['finish_date'] = data['finish_date'].dt.strftime("%m/%y")
# data.loc[data.is_homework == True, :].groupby(['title', 'start_date']).agg({'student_id': 'count'})
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 350677 entries, 0 to 350676
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   progress_id    350677 non-null  object
#  1   module_number  350677 non-null  int64
#  2   lesson_number  350677 non-null  int64
#  3   status         350677 non-null  object
#  4   start_date     350677 non-null  object
#  5   finish_date    334508 non-null  object
#  6   student_id     350677 non-null  object
#  7   course_id      350677 non-null  object
#  8   title          350677 non-null  object
#  9   field          350677 non-null  object
#  10  module_title   350677 non-null  object
#  11  lesson_title   350677 non-null  object
#  12  lesson_token   350677 non-null  object
#  13  is_video       350677 non-null  bool
#  14  is_homework    350677 non-null  bool
# dtypes: bool(2), int64(2), object(11)
# memory usage: 38.1+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 350677 entries, 0 to 350676
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   progress_id    350677 non-null  object
#  1   module_number  350677 non-null  int64
#  2   lesson_number  350677 non-null  int64
#  3   status         350677 non-null  object
#  4   start_date     350677 non-null  datetime64[ns, UTC]
#  5   finish_date    334508 non-null  datetime64[ns, UTC]
#  6   student_id     350677 non-null  object
#  7   course_id      350677 non-null  object
#  8   title          350677 non-null  object
#  9   field          350677 non-null  object
#  10  module_title   350677 non-null  object
#  11  lesson_title   350677 non-null  object
#  12  lesson_token   350677 non-null  object
#  13  is_video       350677 non-null  bool
#  14  is_homework    350677 non-null  bool
# dtypes: bool(2), datetime64[ns, UTC](2), int64(2), object(9)
# memory usage: 38.1+ MB
#                         progress_id  module_number  ...  is_video is_homework
# 0  a387ab916f402cb3fbfffd29f68fd0ce              2  ...      True       False
# 1  a387ab916f402cb3fbfffd29f68fd0ce              1  ...      True       False
# 2  a387ab916f402cb3fbfffd29f68fd0ce              2  ...      True       False
# 3  a387ab916f402cb3fbfffd29f68fd0ce              1  ...      True       False
# 4  a387ab916f402cb3fbfffd29f68fd0ce              1  ...     False        True
#
# [5 rows x 15 columns]

# %%
## переводим к формату "год/месяц"
data_n = data
data_n['start_date'] = data['start_date'].dt.strftime("%y/%m")
data_n['finish_date'] = data['finish_date'].dt.strftime("%y/%m")
data_n.info()
data_n.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 350677 entries, 0 to 350676
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   progress_id    350677 non-null  object
#  1   module_number  350677 non-null  int64
#  2   lesson_number  350677 non-null  int64
#  3   status         350677 non-null  object
#  4   start_date     350677 non-null  object
#  5   finish_date    334508 non-null  object
#  6   student_id     350677 non-null  object
#  7   course_id      350677 non-null  object
#  8   title          350677 non-null  object
#  9   field          350677 non-null  object
#  10  module_title   350677 non-null  object
#  11  lesson_title   350677 non-null  object
#  12  lesson_token   350677 non-null  object
#  13  is_video       350677 non-null  bool
#  14  is_homework    350677 non-null  bool
# dtypes: bool(2), int64(2), object(11)
# memory usage: 38.1+ MB
#                         progress_id  module_number  ...  is_video is_homework
# 0  a387ab916f402cb3fbfffd29f68fd0ce              2  ...      True       False
# 1  a387ab916f402cb3fbfffd29f68fd0ce              1  ...      True       False
# 2  a387ab916f402cb3fbfffd29f68fd0ce              2  ...      True       False
# 3  a387ab916f402cb3fbfffd29f68fd0ce              1  ...      True       False
# 4  a387ab916f402cb3fbfffd29f68fd0ce              1  ...     False        True
#
# [5 rows x 15 columns]

# %%
data_n[data_n['title'] == 'Excel Базовый']
# Out:
#                              progress_id  module_number  ...  is_video is_homework
# 427     254e96b86d572b4685b06afd26941c3f              2  ...      True       False
# 428     254e96b86d572b4685b06afd26941c3f              1  ...     False        True
# 429     254e96b86d572b4685b06afd26941c3f              8  ...      True       False
# 430     254e96b86d572b4685b06afd26941c3f              6  ...      True       False
# 431     254e96b86d572b4685b06afd26941c3f              2  ...      True       False
# ...                                  ...            ...  ...       ...         ...
# 350408  ec0d53d87ce9162416214d0ce89938f0              2  ...      True       False
# 350409  ec0d53d87ce9162416214d0ce89938f0              1  ...      True       False
# 350410  ec0d53d87ce9162416214d0ce89938f0              1  ...      True       False
# 350411  ec0d53d87ce9162416214d0ce89938f0              1  ...      True       False
# 350412  ec0d53d87ce9162416214d0ce89938f0              1  ...      True       False
#
# [18666 rows x 15 columns]

# %%
## первые домашки к каждому курсу
courses_with_homework = data_n.loc[data.is_homework == True, :][['title', 'module_number', 'lesson_number']].drop_duplicates()
courses_with_homework = courses_with_homework.sort_values(by=['title', 'module_number', 'lesson_number'])
courses_with_homework = courses_with_homework.groupby(by=['title']).first().reset_index()
courses_with_homework
# Out:
#                                   title  module_number  lesson_number
# 0                         Excel Базовый              1             11
# 1                      Java-разработчик              1              8
# 2               Java-разработчик c нуля              1              7
# 3                     JavaScript с нуля              1              7
# 4   PHP-разработчик с 0 до PRO. Часть 1              1              5
# 5              SMM-маркетолог от А до Я              1              6
# 6                             UX-дизайн              1              8
# 7                  Анимация интерфейсов              1              3
# 8        Веб-вёрстка для начинающих 2.0              1              6
# 9                    Веб-дизайн PRO 2.0              1              6
# 10                   Веб-дизайн Базовый              3              2
# 11                Веб-дизайн с нуля 2.0              1              9
# 12                      Веб-разработчик              1              2
# 13        Интернет-маркетолог от Ingate              1              7
# 14        Руководитель digital-проектов              1              4

# %%
growth_stud = pd.merge(data_n, courses_with_homework, how='inner', right_on=['title', 'module_number', 'lesson_number'], left_on=['title', 'module_number', 'lesson_number']).groupby(['title', 'module_number', 'lesson_number', 'start_date']).agg('count')['student_id']
growth_stud = growth_stud.groupby(['title', 'module_number', 'lesson_number'])
# for i, group in growth_stud:
#   # print(i)
#   print(group)
#   print('################')

# %%
##группируем по курсам и по дате старта
# growth_stud = data_n.loc[data.is_homework == True, :].groupby(['title','start_date']).agg({'student_id': 'count'}).reset_index()#.sort_values('start_date', ascending=True)
##создаю Series с датами от марта 2016 до июля 2019 в формате "год/месяц"
all_dates = pd.date_range('2016-03','2019-07', 
              freq='MS').strftime("%y/%m").to_frame(name='start_date')
# print(all_dates)
# growth_stud.loc[growth_stud.title == 'Excel Базовый', :]
# fig, ax = plt.subplots()
plt.figure(figsize=(17, 10))

labels = list()
##смотрю сгруппированные данные
for name,values in growth_stud:
  # print(values.columns)
  # print(all_dates)
  # print(values.iloc[0, 0])
  values = values.reset_index()
  ###  соединяем все даты от 2016 до 2019 с приростом студентов, чтобы даты для всех групп были одинаковыми 
  all_dates['title'] = values.iloc[0, 0]
  res = pd.merge(values, all_dates, how='right')
  res.sort_values('start_date', inplace=True)
  # print(res)
  ### отрисовываем получившиеся данные
  dates = res['start_date']
  res[res['student_id'].isna()]['student_id'] = 0
  growth = res['student_id']
  plt.plot(dates, growth, label=name[0])
  plt.xticks(rotation=90)
  # print(name[0])
  labels.append(name[0])
  plt.legend()
plt.xlabel('Год/Месяц', fontsize=12, labelpad=12)
plt.ylabel('Количество студентов', fontsize=12, labelpad=12)
plt.box(False)
  # print(values)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
growth_stud = pd.merge(data_n, courses_with_homework, how='inner', right_on=['title', 'module_number', 'lesson_number'], left_on=['title', 'module_number', 'lesson_number']).groupby(['title', 'module_number', 'lesson_number', 'start_date', 'finish_date']).agg('count')['student_id']
growth_stud = growth_stud.reset_index()
growth_stud.head()
# Out:
#            title  module_number  ...  finish_date student_id
# 0  Excel Базовый              1  ...        18/02          6
# 1  Excel Базовый              1  ...        18/03          2
# 2  Excel Базовый              1  ...        18/05          3
# 3  Excel Базовый              1  ...        18/06          4
# 4  Excel Базовый              1  ...        18/07          4
#
# [5 rows x 6 columns]

# %%
# growth_stud['start_date'].("%y/%m")
data_n['start_date'] = pd.to_datetime(data_n['start_date'], format=("%y/%m"))
data_n['finish_date'] = pd.to_datetime(data_n['finish_date'], format=("%y/%m"))
# growth_stud['start_date'] = growth_stud['start_date'].dt.strftime("%y/%m")
# growth_stud.loc[0, 'start_date'] > growth_stud.loc[1, 'start_date']
all_dates = pd.date_range('2016-03','2019-07', 
              freq='MS')
# all_dates.iloc[:,0].to_list()
data_n.head()
# Out:
#                         progress_id  module_number  ...  is_video is_homework
# 0  a387ab916f402cb3fbfffd29f68fd0ce              2  ...      True       False
# 1  a387ab916f402cb3fbfffd29f68fd0ce              1  ...      True       False
# 2  a387ab916f402cb3fbfffd29f68fd0ce              2  ...      True       False
# 3  a387ab916f402cb3fbfffd29f68fd0ce              1  ...      True       False
# 4  a387ab916f402cb3fbfffd29f68fd0ce              1  ...     False        True
#
# [5 rows x 15 columns]

# %%
def dates_in_interval(date, interval):
  return interval[0] <= date <= interval[1]

# надо прогнать все значения date_n отфильтрованные по homework
# for date in all_dates:
all_dates[30]


data_n[['start_date', 'finish_date']].apply(lambda x: dates_in_interval(all_dates[29], x),
                                            axis=1).sum()
  # print()
  # print(date)
# Out:
# 16946

# %%
len(data_n)
# Out:
# 350677

# %%
growth = list()
plt.figure(figsize=(17, 10))
for name, group in data_n.groupby('title'):
  for date in all_dates:
    growth.append(group[['start_date', 'finish_date']].apply(lambda x: dates_in_interval(date, x), axis=1).sum())
  plt.plot(all_dates, growth, label=name)
  plt.xticks(rotation=90)
  growth = list()
  print('#############')
  plt.legend()
plt.xlabel('Год/Месяц')
plt.ylabel('Количество студентов')
plt.box(False)
# Out:
# #############
# #############
# #############
# #############
# #############
# #############
# #############
# #############
# #############
# #############
# #############
# #############
# #############
# #############
# #############

# %%
growth = list()
plt.figure(figsize=(17, 10))

for date in all_dates:
  growth.append(data_n[['start_date', 'finish_date']].apply(lambda x: dates_in_interval(date, x), axis=1).sum())
plt.plot(all_dates, growth, label='Общий прирост студентов')
plt.xticks(rotation=90)

print('#############')
plt.legend()
plt.xlabel('Год/Месяц')
plt.ylabel('Количество студентов')
plt.box(False)
# Out:
# #############

# %%
data_n.groupby('title').first()
# Out:
#                                                           progress_id  ...  is_homework
# title                                                                  ...
# Excel Базовый                        254e96b86d572b4685b06afd26941c3f  ...        False
# Java-разработчик                     e30d2280f12173343846894a9d34b7d5  ...        False
# Java-разработчик c нуля              d6b2e7d72e8b5143d0f7a523b6cd3687  ...        False
# JavaScript с нуля                    2d0f54a3b13dac71dbb598e56bf86065  ...        False
# PHP-разработчик с 0 до PRO. Часть 1  eb111cf6c607887d7cf1d6302d4afd39  ...        False
# SMM-маркетолог от А до Я             0c70a7047707efd7c1c0931a8432faac  ...        False
# UX-дизайн                            3cd79468e1c5336964abb8bff6d6d0a6  ...        False
# Анимация интерфейсов                 e4897c239bcf0cbf7b081c8de86eb893  ...        False
# Веб-вёрстка для начинающих 2.0       e0bdd91335a3836a138395eefa0f656d  ...        False
# Веб-дизайн PRO 2.0                   a387ab916f402cb3fbfffd29f68fd0ce  ...        False
# Веб-дизайн Базовый                   6168c9bc4533ccd0311be6012bc8ef6f  ...        False
# Веб-дизайн с нуля 2.0                000962791295398b5ec7bc24f05269ac  ...        False
# Веб-разработчик                      cce45ced8f66b2b4432bdfbe04223168  ...        False
# Интернет-маркетолог от Ingate        a97393fe164b448e7231c07d48c82f9e  ...        False
# Руководитель digital-проектов        17cc1bdd5d69eda56e3cca1c70cbae36  ...        False
#
# [15 rows x 14 columns]

# %% [markdown]
# ## 3. Выявление проблемных модулей
#
# 1. **(p)** Рассчитать минимальное, максимальное, среднее, медианное время прохождения каждого модуля (разность между временем начала и окончания выполнения домашней работы) для каждого курса. Если домашних заданий в модуле несколько, то считать разность между временем начала выполнения первой домашней работы и временем окончания выполнения последней домашней работы в модуле
# 2. **(m)** На основании первого пункта построить line-graph с медианным временем прохождения каждого модуля для каждого курса. 15 графиков. Графики должны иметь заголовки
# 3. **(p)**  Чтобы выявить сезонность, посчитать медианное время выполнения домашней работы по месяцам (12 месяцев, январь-декабрь) для каждого курса.
# 4. **(m)** На основании третьего пункта построить line-graph, на который будут нанесены линии для каждого курса с медианным временем выполнения домашней работы по месяцам. 15 линий на графике. График должен иметь заголовок. Ось, отражающая время прохождения, должна быть подписана. Линия для каждого курса должна иметь свой цвет (нужна легенда). Рамок у графика быть не должно  ⭐
# 5. На основании рассчитанных значений сделайте аналитический вывод (должен быть полным и покрывать все полученные выше метрики)

# %%
data.groupby('module_title').agg({})
data.head()
# Out:
#                         progress_id  module_number  ...  is_video is_homework
# 0  a387ab916f402cb3fbfffd29f68fd0ce              2  ...      True       False
# 1  a387ab916f402cb3fbfffd29f68fd0ce              1  ...      True       False
# 2  a387ab916f402cb3fbfffd29f68fd0ce              2  ...      True       False
# 3  a387ab916f402cb3fbfffd29f68fd0ce              1  ...      True       False
# 4  a387ab916f402cb3fbfffd29f68fd0ce              1  ...     False        True
#
# [5 rows x 15 columns]

# %%
data['dif_date'] = data.finish_date - data.start_date
data.head()
# Out:
#                         progress_id  module_number  ...  is_homework dif_date
# 0  a387ab916f402cb3fbfffd29f68fd0ce              2  ...        False   0 days
# 1  a387ab916f402cb3fbfffd29f68fd0ce              1  ...        False   0 days
# 2  a387ab916f402cb3fbfffd29f68fd0ce              2  ...        False   0 days
# 3  a387ab916f402cb3fbfffd29f68fd0ce              1  ...        False   0 days
# 4  a387ab916f402cb3fbfffd29f68fd0ce              1  ...         True   0 days
#
# [5 rows x 16 columns]

# %% [markdown]
# ## 4. Расчет конверсии
#
# 1. **(p)** Посчитать конверсию перехода студентов из одного модуля в другой на каждом курсе. Формула: отношение количества студентов, приступивших к выполнению домашнего задания в этом модуле (если дз в модуле несколько, то считать по первому дз в модуле), к количеству студентов, сдавших задание в предыдущем модуле (если дз в модуле несколько, то считать по последнему дз в модуле).
# 2. **(m)** Постройте bar-chart, отражающий конверсию перехода студентов из одного модуля в другой на каждом курсе. График должен иметь заголовок. Ticks нужно развернуть так, чтобы они были читаемы
# 3. **(m)** Постройте горизонтальный (столбцы должны располагаться горизонтально) bar-chart, отражающий конверсию перехода студентов из одного модуля в другой на каждом курсе. 15 графиков. Графики должны иметь заголовки. Ticks должны содержать номер и название модуля. Цвет столбцов графиков должен содержать информацию о сфере, к которой относится курс (нужна легенда). Прозрачность должна стоять на отметке 0.1. На графики должна быть нанесена линия медианы конверсии для каждого курса. У медианы должен быть свой цвет. Рамок у графиков быть не должно ⭐
# 4. На основании рассчитанных значений сделайте аналитический вывод (должен быть полным и покрывать все полученные выше метрики)

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ## 5. Метрика успеваемости
#
# &nbsp;&nbsp;&nbsp;&nbsp;*(необязательное задание)*
#
# Иногда студенты берут курсы, которые оказываются для них неподъемными. Это может быть как по причинам недостаточной изначальной подготовки, так и по причинам, связанным с низкой мотивацией студента. Для улучшения качества контента полезно выявить причину. На основании имеющихся данных придумайте метрику успеваемости студента. **Обоснуйте ее.** Выявите таких студентов на каждом курсе, чтобы предоставить продюсерам список проблемных студентов.

# %%
### YOUR CODE HERE ###
